# %%
# import python libraries

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
# import csv file
df = pd.read_csv("student_data.csv")      # save as CSV

# %%
df.shape
# Out:
# (100, 10)

# %%
df.head()
# Out:
#   Student ID  Student Name Class  Attendance (%)  Math  Science  English  \
# 0       S001  Aditi Sharma   10A              92    88       91       84
# 1       S002   Rohan Verma   10A              85    72       68       75
# 2       S003    Meera Nair   10A              97    95       93       90
# 3       S004   Arjun Patel   10B              78    66       70       60
# 4       S005     Sana Khan   10B              88    81       85       79
#
#    Social Studies  Average Score Grade
# 0              89           88.0     A
# 1              70           71.3     B
# 2              92           92.5    A+
# 3              65           65.3     C
# 4              80           81.3    B+

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student ID      100 non-null    object
#  1   Student Name    100 non-null    object
#  2   Class           100 non-null    object
#  3   Attendance (%)  100 non-null    int64
#  4   Math            100 non-null    int64
#  5   Science         100 non-null    int64
#  6   English         100 non-null    int64
#  7   Social Studies  100 non-null    int64
#  8   Average Score   100 non-null    float64
#  9   Grade           100 non-null    object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 7.9+ KB

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# Student ID        0
# Student Name      0
# Class             0
# Attendance (%)    0
# Math              0
# Science           0
# English           0
# Social Studies    0
# Average Score     0
# Grade             0
# dtype: int64

# %%
# drop null values
df.dropna(inplace=True)

# %%
df['Average Score'].dtypes
# Out:
# dtype('float64')

# %%
df.columns
# Out:
# Index(['Student ID', 'Student Name', 'Class', 'Attendance (%)', 'Math',
#        'Science', 'English', 'Social Studies', 'Average Score', 'Grade'],
#       dtype='object')

# %%
#rename column
df.rename(columns= {'Average Score':'Average'})
# Out:
#    Student ID   Student Name Class  Attendance (%)  Math  Science  English  \
# 0        S001   Aditi Sharma   10A              92    88       91       84
# 1        S002    Rohan Verma   10A              85    72       68       75
# 2        S003     Meera Nair   10A              97    95       93       90
# 3        S004    Arjun Patel   10B              78    66       70       60
# 4        S005      Sana Khan   10B              88    81       85       79
# ..        ...            ...   ...             ...   ...      ...      ...
# 95       S096   Vanya Kapoor   10C              92    90       88       89
# 96       S097   Tejas Pillai   10C              68    55       57       56
# 97       S098   Avantika Das   10C              86    82       80       84
# 98       S099  Saket Agrawal   10C              93    92       90       91
# 99       S100    Sonam Bhatt   10C              74    64       60       62
#
#     Social Studies  Average Grade
# ...

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
df.describe()
# Out:
#        Attendance (%)        Math     Science     English  Social Studies  \
# count      100.000000  100.000000  100.000000  100.000000      100.000000
# mean        84.350000   78.090000   78.220000   78.400000       78.300000
# std          8.718232   12.839408   12.404447   12.397458       11.508012
# min         67.000000   52.000000   48.000000   50.000000       55.000000
# 25%         77.750000   67.500000   69.500000   69.750000       69.750000
# 50%         86.000000   80.500000   80.000000   81.000000       79.000000
# 75%         91.250000   89.000000   88.250000   89.000000       88.250000
# max         98.000000   98.000000   99.000000   97.000000       95.000000
#
#        Average Score
# count     100.000000
# mean       78.315000
# std        12.192574
# min        51.300000
# 25%        68.875000
# 50%        81.300000
# 75%        88.500000
# max        96.500000

# %%
df.columns
# Out:
# Index(['Student ID', 'Student Name', 'Class', 'Attendance (%)', 'Math',
#        'Science', 'English', 'Social Studies', 'Average Score', 'Grade'],
#       dtype='object')

# %%
# use describe() for specific columns
df[['English', 'Science', 'Math']].describe()
# Out:
#           English     Science        Math
# count  100.000000  100.000000  100.000000
# mean    78.400000   78.220000   78.090000
# std     12.397458   12.404447   12.839408
# min     50.000000   48.000000   52.000000
# 25%     69.750000   69.500000   67.500000
# 50%     81.000000   80.000000   80.500000
# 75%     89.000000   88.250000   89.000000
# max     97.000000   99.000000   98.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Class

# %%
# plotting a bar chart for Gender and it's count

ax = sns.countplot(x = 'Class',data = df)
sns.set(rc={'figure.figsize':(5,11)})

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# *From above graphs we can see which section have max and min no of students of class 10th*

# %%
subject_avg = df[['Math', 'Science', 'English','Social Studies']].mean()
print(subject_avg)
# Out:
# Math              78.09
# Science           78.22
# English           78.40
# Social Studies    78.30
# dtype: float64

# %%
subject_avg.plot(kind = 'bar', color = 'lightpink')
plt.title('Average marks per subject')
plt.xlabel('Subjects')
plt.ylabel('average score')
plt.tight_layout()
sns.set(rc={'figure.figsize':(10,10)})
plt.show()

# %% [markdown]
# ***From the above bar graph we can analyze the average marks scored by all students in each subject***

# %%
# Student name  vs Average marks
avg = df.groupby(['Student Name'], as_index=False)['Average Score'].sum().sort_values(by='Average Score', ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x = 'Student Name',y= 'Average Score' ,data = avg,color = 'lightgreen')
# Out:
# <Axes: xlabel='Student Name', ylabel='Average Score'>

# %% [markdown]
# ***from above analysis we can find the topper student by average score***

# %%
avg = df.groupby(['Student Name'], as_index=False)['Attendance (%)'].sum().sort_values(by='Attendance (%)', ascending=False).head(20)
sns.set(rc={'figure.figsize':(25,7)})
sns.barplot(x = 'Student Name',y= 'Attendance (%)' ,data = avg , color = 'indigo')
# Out:
# <Axes: xlabel='Student Name', ylabel='Attendance (%)'>

# %% [markdown]
# ***frome above analysis we can see that which student is present in most classes***

# %%
plt.bar(df['Attendance (%)'],df['Average Score'],color = 'red')
plt.xlabel('Attendance (%)')
plt.ylabel('Average score')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ***from above bar we can compare that students which have high attendance rate have high average score***

# %%
sns.set_context("poster")
ax = sns.barplot(data = df, x = 'Grade' , y = 'Attendance (%)', hue = 'Class')
sns.set_context("poster")
sns.set(rc={'figure.figsize':(20,20)})

# %% [markdown]
# ***using seaborn library we can see that grade vs attendance relationship***

# %%
df['performance category'] = df['Average Score'].apply(lambda x : 'High performer' if x>= 75 else 'Low performer')
sns.countplot(data = df , x = 'performance category' , hue = 'Class')
sns.set(rc={'figure.figsize':(5,10)})
plt.title('Count of High Performer vs Low Performer')
# Out:
# Text(0.5, 1.0, 'Count of High Performer vs Low Performer')

# %%
subjects = ['Math','English','Social Studies','Science']
df_small = df.head(10)
df_melted = df_small.melt(id_vars = ['Student Name'],value_vars = subjects,var_name = 'Subjects',value_name = 'Marks')
sns.barplot(data = df_melted , x = 'Student Name' , y = 'Marks' , hue = 'Subjects')
sns.set(rc={'figure.figsize':(25,10)})

# %% [markdown]
# ***from above grouped graph we can compare the scores over different subjects of a particular student. Thus helps in determing the weak points of the student***

# %%
columns = ['Attendance (%)','Average Score', 'Math' , 'Science' , 'English']
sns.heatmap(data = df[columns].corr() , annot = True , cmap = 'Blues')
sns.set(rc={'figure.figsize':(20,10)})

# %% [markdown]
# ***using heatmaps we can see that correlation beteween over different columns***

# %%
ax = sns.countplot(data = df , x = 'Grade' , hue = 'Class')
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ***using seaborn , we can see performance of students of different section***

# %% [markdown]
# ### scatter plot

# %%
sns.scatterplot(data = df , color = 'orange' , x = 'Attendance (%)' , y = 'Math' , hue = 'Class')

sns.set_context('poster')
sns.set(rc={'figure.figsize':(5,5)})

# %% [markdown]
# ## Conclusion:
#
# ###

# %% [markdown]
# Most of the students which high attendace percentage have somehow better average marks and have good grades

# %% [markdown]
# complete project on YouTube: https://www.youtube.com/@RishabhMishraOfficial
#
# complete project on GitHub: https://github.com/rishabhnmishra/Python_Diwali_Sales_Analysis

# %% [markdown]
# Thank you!
